# %%
import pandas as pd
Series = pd.Series(data=[78, 92, 36,54,89])
Series
# Out:
# 0    78
# 1    92
# 2    36
# 3    54
# 4    89
# dtype: int64

# %%
Series.values
# Out:
# array([78, 92, 36, 54, 89], dtype=int64)

# %%
Series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
Series[1]
# Out:
# 92

# %%
Series[1:3]
# Out:
# 1    92
# 2    36
# dtype: int64

# %%
data = pd.Series(data=[700000, 800000, 1600000, 1800000,3000000],index = ['swift','jazz','civic','altis','gallardo'])
data
# Out:
# swift        700000
# jazz         800000
# civic       1600000
# altis       1800000
# gallardo    3000000
# dtype: int64

# %%
data['swift']
# Out:
# 700000

# %%
data['jazz':'gallardo']
# Out:
# jazz         800000
# civic       1600000
# altis       1800000
# gallardo    3000000
# dtype: int64

# %%
car_price_dict = {'swift':700000,
                 'jazz':800000,
                 'civic':160000,
                 'atlis':1800000,
                 'gallardo':3000000
                 }
car_price = pd.Series(car_price_dict)
car_price
# Out:
# swift        700000
# jazz         800000
# civic        160000
# atlis       1800000
# gallardo    3000000
# dtype: int64

# %%
car_price_dict = {'swift':700000,
                 'jazz':800000,
                 'civic':160000,
                 'atlis':1800000,
                 'gallardo':3000000
                 }
car_price = pd.Series(car_price_dict)
car_man_dict = {'swift':'maruti',
                'jazz':'honda',
                 'civic':'honda',
                 'atlis':'toyota', 
                 'gallardo':'lamborghini'}
car_man = pd.Series(car_man_dict)
print(car_price)
print(car_man)
# Out:
# swift        700000
# jazz         800000
# civic        160000
# atlis       1800000
# gallardo    3000000
# dtype: int64
# swift            maruti
# jazz              honda
# civic             honda
# atlis            toyota
# gallardo    lamborghini
# dtype: object

# %%
import pandas as pd
car_price_dict = {'swift':700000,
                 'jazz':800000,
                 'civic':160000,
                 'atlis':1800000,
                 'gallardo':3000000
                 }
car_price = pd.Series(car_price_dict)
car_price
pd.DataFrame(car_price, columns=['car price'])
# Out:
#           car price
# swift        700000
# jazz         800000
# civic        160000
# atlis       1800000
# gallardo    3000000

# %%
data = [{'Name': 'Subodh', 'Marks': 28},
        {'Name': 'Ram', 'Marks': 27}, 
        {'Name': 'Abdul', 'Marks': 26}, 
        {'Name': 'John', 'Marks': 28}]
pd.DataFrame(data)
# Out:
#      Name  Marks
# 0  Subodh     28
# 1     Ram     27
# 2   Abdul     26
# 3    John     28

# %%
pd.DataFrame([{'Subodh':20, 'Ram':25},
              {'Abdul':29, 'John':24}], 
              index = ['Mathematics', 'Physics'])
# Out:
#              Subodh   Ram  Abdul  John
# Mathematics    20.0  25.0    NaN   NaN
# Physics         NaN   NaN   29.0  24.0

# %%
import pandas as pd
#Using dictionary to create a series
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
car = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
car
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
import pandas as pd
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
print(car_price)
print(car_man)
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# dtype: object

# %%
cars = pd.DataFrame({'Price': car_price , 
                    'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
cars['Price']
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# Name: Price, dtype: int64

# %%
cars['Manufacturer']
# Out:
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# Name: Manufacturer, dtype: object

# %%
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_price

pd.DataFrame(car_price, columns=['Car Price'])
# Out:
#           Car Price
# Swift        700000
# Jazz         800000
# Civic       1600000
# Altis       1800000
# Gallardo   30000000

# %%
import pandas as pd
data_csv = pd.read_csv('dataset/auto-mpg.csv',)
data_csv
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data = [{'Name': 'Subodh', 'Marks': 28},
        {'Name': 'Ram', 'Marks': 27}, 
        {'Name': 'Abdul', 'Marks': 26}, 
        {'Name': 'John', 'Marks': 28}]
pd.DataFrame(data)
# Out:
#      Name  Marks
# 0  Subodh     28
# 1     Ram     27
# 2   Abdul     26
# 3    John     28

# %%
pd.DataFrame([{'Subodh':20, 'Ram':25},
              {'Abdul':29, 'John':24}], 
              index = ['Mathematics', 'Physics'])
# Out:
#              Subodh   Ram  Abdul  John
# Mathematics    20.0  25.0    NaN   NaN
# Physics         NaN   NaN   29.0  24.0

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#Using dictionary to create a series
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
cars = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
df.head
# Out:
# <bound method NDFrame.head of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 398, dtype: object

# %%
df[['name']]
# Out:
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 1 columns]

# %%
df[['name','origin','model_year','mpg']]
# Out:
#                           name  origin  model_year   mpg
# 0    chevrolet chevelle malibu       1          70  18.0
# 1            buick skylark 320       1          70  15.0
# 2           plymouth satellite       1          70  18.0
# 3                amc rebel sst       1          70  16.0
# 4                  ford torino       1          70  17.0
# ..                         ...     ...         ...   ...
# 393            ford mustang gl       1          82  27.0
# 394                  vw pickup       2          82  44.0
# 395              dodge rampage       1          82  32.0
# 396                ford ranger       1          82  28.0
# 397                 chevy s-10       1          82  31.0
#
# [398 rows x 4 columns]

# %%
df_head = df.head()
df_head.set_index('name',inplace = True)
df.head
# Out:
# <bound method NDFrame.head of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.iloc[2,1]
# Out:
# 8

# %%
df.iloc[2,-1]
# Out:
# 'plymouth satellite'

# %%
df.iloc[1:5, 4:6]
# Out:
#    weight  acceleration
# 1    3693          11.5
# 2    3436          11.0
# 3    3433          12.0
# 4    3449          10.5

# %%
#creating a subset using head. 'df' refers to XYZ Custom Cars DataFrame.
df_head = df.head()
#Setting name as custom index
df_head.set_index('name', inplace = True)
df_head.loc['buick skylark 320': 'amc rebel sst']
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
#
#                     acceleration  model_year  origin
# name
# buick skylark 320           11.5          70       1
# plymouth satellite          11.0          70       1
# amc rebel sst               12.0          70       1

# %%
df.loc[0:5, ['cylinders', 'horsepower','name']]
# Out:
#    cylinders horsepower                       name
# 0          8        130  chevrolet chevelle malibu
# 1          8        165          buick skylark 320
# 2          8        150         plymouth satellite
# 3          8        150              amc rebel sst
# 4          8        140                ford torino
# 5          8        198           ford galaxie 500

# %%
df.fillna(23.56)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 import pandas as pd
# ----> 2 data_csv = pd.read_csv('dataset/auto-mpg1.csv')
#       3 data_csv
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_head = df.head()
df_head.set_index('name',inplace=True)
df_head
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
df.iloc[2,1]
# Out:
# 8

# %%
df.iloc[2,-1]
# Out:
# 'plymouth satellite'

# %%
df.iloc[1:5, 2:6]
# Out:
#    displacement horsepower  weight  acceleration
# 1         350.0        165    3693          11.5
# 2         318.0        150    3436          11.0
# 3         304.0        150    3433          12.0
# 4         302.0        140    3449          10.5

# %%
df_head = df.head()
df_head.set_index('name',inplace = True)
df_head.loc['buick skylark 320':'amc rebel sst']
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
#
#                     acceleration  model_year  origin
# name
# buick skylark 320           11.5          70       1
# plymouth satellite          11.0          70       1
# amc rebel sst               12.0          70       1

# %%
df.loc[0:5, ['cylinders','horsepower','name']]
# Out:
#    cylinders horsepower                       name
# 0          8        130  chevrolet chevelle malibu
# 1          8        165          buick skylark 320
# 2          8        150         plymouth satellite
# 3          8        150              amc rebel sst
# 4          8        140                ford torino
# 5          8        198           ford galaxie 500

# %%
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
marks_df['Total'] = marks_df['Chemistry'] + marks_df['Physics'] + marks_df['Mathematics'] + marks_df['English']
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English  Total
# Subodh         67       45           50       19    181
# Ram            90       92           87       90    359
# Abdul          66       72           81       72    291
# John           32       40           12       68    152

# %%
marks_df.drop(columns = 'Total', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 marks_df.drop(columns = 'Total', inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
df.loc[df['model_year'] == 72].head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 57  24.0          4         113.0         95    2278          15.5
# 58  25.0          4          97.5         80    2126          17.0
# 59  23.0          4          97.0         54    2254          23.5
# 60  20.0          4         140.0         90    2408          19.5
# 61  21.0          4         122.0         86    2226          16.5
#
#     model_year  origin                   name
# 57          72       3  toyota corona hardtop
# 58          72       1     dodge colt hardtop
# 59          72       2      volkswagen type 3
# 60          72       1         chevrolet vega
# 61          72       1    ford pinto runabout

# %%
[df['model_year']==72]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  393    False
#  394    False
#  395    False
#  396    False
#  397    False
#  Name: model_year, Length: 398, dtype: bool]

# %%
df.loc[(df['origin'] == 3) & (df['cylinders'] == 6)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 123  20.0          6         156.0        122    2807          13.5
# 210  19.0          6         156.0        108    2930          15.5
# 241  22.0          6         146.0         97    2815          14.5
# 333  32.7          6         168.0        132    2910          11.4
# 361  25.4          6         168.0        116    2900          12.6
# 362  24.2          6         146.0        120    2930          13.8
#
#      model_year  origin               name
# 123          73       3     toyota mark ii
# 210          76       3     toyota mark ii
# 241          77       3         datsun 810
# 333          80       3      datsun 280-zx
# 361          81       3    toyota cressida
# 362          81       3  datsun 810 maxima

# %%
df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce')

# %%
df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0        70.0    2074          19.5
# 52   30.0          4          88.0        76.0    2065          14.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# ..    ...        ...           ...         ...     ...           ...
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year  origin                 name
# 51           71       2          peugeot 304
# 52           71       2            fiat 124b
# ...

# %%
df.loc[(df['displacement'] > 262) & (df['horsepower'] > 126) & (df['weight'] >=2800) & (df['weight'] <= 3600)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year  origin                          name
# 0            70       1     chevrolet chevelle malibu
# ...

# %%
df.loc[(df['horsepower'] > 140) & (df['weight'] >=4500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 25   10.0          8         360.0       215.0    4615          14.0
# 28    9.0          8         304.0       193.0    4732          18.5
# 42   12.0          8         383.0       180.0    4955          11.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 67   11.0          8         429.0       208.0    4633          11.0
# 68   13.0          8         350.0       155.0    4502          13.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 94   13.0          8         440.0       215.0    4735          11.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 104  12.0          8         400.0       167.0    4906          12.5
# 105  13.0          8         360.0       170.0    4654          13.0
# ...

# %%
df.loc[(df['acceleration'] > 17) & (df['weight'] < 2223)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19   26.0          4          97.0        46.0    1835          20.5
# 32   25.0          4          98.0         NaN    2046          19.0
# 51   30.0          4          79.0        70.0    2074          19.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 55   27.0          4          97.0        60.0    1834          19.0
# 56   26.0          4          91.0        70.0    1955          20.5
# 79   26.0          4          96.0        69.0    2189          18.0
# 102  26.0          4          97.0        46.0    1950          21.0
# 117  29.0          4          68.0        49.0    1867          19.5
# 129  31.0          4          79.0        67.0    1950          19.0
# 131  32.0          4          71.0        65.0    1836          21.0
# 145  32.0          4          83.0        61.0    2003          19.0
# ...

# %%
marks = [{'Chemistry': 67, 'Physics': 45, 'Mathematics': 50, 'English' : 19},
        {'Chemistry': 90, 'Physics': 92, 'Mathematics': 87, 'English' : 90}, 
        {'Chemistry': 66, 'Physics': 72, 'Mathematics': 81, 'English' : 72}, 
        {'Chemistry': 32, 'Physics': 40, 'Mathematics': 12, 'English' : 68}]
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
f = marks_df < 33
marks_df.mask(f, 'fail')
# Out:
#        Chemistry  Physics Mathematics English
# Subodh        67       45          50    fail
# Ram           90       92          87      90
# Abdul         66       72          81      72
# John        fail       40        fail      68

# %%
df.sort_values(by = 'cylinders')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0       150.0    3672          11.5
# 285  17.0          8         305.0       130.0    3840          15.4
# 286  17.6          8         302.0       129.0    3725          13.4
# 92   13.0          8         351.0       158.0    4363          13.0
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year  origin                       name
# 111          73       3                  maxda rx3
# ...

# %%
df.sort_values(['acceleration','horsepower'],ascending = (1,0))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 9    15.0          8         390.0       190.0    3850           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
# ..    ...        ...           ...         ...     ...           ...
# 195  29.0          4          85.0        52.0    2035          22.2
# 59   23.0          4          97.0        54.0    2254          23.5
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 299  27.2          4         141.0        71.0    3190          24.8
#
#      model_year  origin                name
# 11           70       1  plymouth 'cuda 340
# 7            70       1   plymouth fury iii
# ...

# %%
import pandas as pd
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
import numpy as np
encrypted_marks = np.sin(marks_df)
encrypted_marks
# Out:
#         Chemistry   Physics  Mathematics   English
# Subodh  -0.855520  0.850904    -0.262375  0.149877
# Ram      0.893997 -0.779466    -0.821818  0.893997
# Abdul   -0.026551  0.253823    -0.629888  0.253823
# John     0.551427  0.745113    -0.536573 -0.897928

# %%
encrypted_marks.reset_index(inplace = True)
encrypted_marks
# Out:
#     index  Chemistry   Physics  Mathematics   English
# 0  Subodh  -0.855520  0.850904    -0.262375  0.149877
# 1     Ram   0.893997 -0.779466    -0.821818  0.893997
# 2   Abdul  -0.026551  0.253823    -0.629888  0.253823
# 3    John   0.551427  0.745113    -0.536573 -0.897928

# %%
new_marks = marks_df + 5
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       50           55       24
# Ram            95       97           92       95
# Abdul          71       77           86       77
# John           37       45           17       73

# %%
new_marks = marks_df + [5,10,10,2]
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       55           60       21
# Ram            95      102           97       92
# Abdul          71       82           91       74
# John           37       50           22       70

# %%
#Creating the DataFrame
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['James', 'Lee', 'Anderson', 'John'])

# %%
marks_df.apply(np.sum, axis = 0)
# Out:
# Chemistry      255
# Physics        249
# Mathematics    230
# English        249
# dtype: int64

# %%
marks_df.apply(np.sum, axis = 1)
# Out:
# James       181
# Lee         359
# Anderson    291
# John        152
# dtype: int64

# %%
marks_df.apply(func = np.mean, axis = 0, result_type = 'broadcast')
# Out:
#           Chemistry  Physics  Mathematics  English
# James            63       62           57       62
# Lee              63       62           57       62
# Anderson         63       62           57       62
# John             63       62           57       62

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
list1 = [col for col in df.columns if df[col].dtype in ['float', 'int64']]
df[list1].agg(['min', 'max'])
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  origin
# min   9.0          3          68.0    1613           8.0          70       1
# max  46.6          8         455.0    5140          24.8          82       3

# %%
df.groupby(['model_year']).count()[['name']]
# Out:
#             name
# model_year
# 70            29
# 71            28
# 72            28
# 73            40
# 74            27
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            29
# 81            29
# 82            31

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#Using list comprehension to get the numerical columns
list1 = [col for col in df.columns if df[col].dtype in ['float', 'int64']]
df[list1].agg(['min', 'max'])
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  origin
# min   9.0          3          68.0    1613           8.0          70       1
# max  46.6          8         455.0    5140          24.8          82       3

# %%
df.groupby(['model_year']).count()[['name']]
# Out:
#             name
# model_year
# 70            29
# 71            28
# 72            28
# 73            40
# 74            27
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            29
# 81            29
# 82            31

# %%
df.groupby(by='horsepower').count()[['model_year','cylinders']]
# Out:
#             model_year  cylinders
# horsepower
# 100                 17         17
# 102                  1          1
# 103                  1          1
# 105                 12         12
# 107                  1          1
# ...                ...        ...
# 95                  14         14
# 96                   3          3
# 97                   9          9
# 98                   2          2
# ?                    6          6
#
# [94 rows x 2 columns]

# %%
df.groupby(by='model_year').mean().sort_values('acceleration')[['acceleration']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\202178759.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by='model_year').mean().sort_values('acceleration')[['acceleration']]
#             acceleration
# model_year
# 70             12.948276
# 73             14.312500
# 72             15.125000
# 71             15.142857
# 77             15.435714
# 78             15.805556
# 79             15.813793
# 76             15.941176
# 75             16.050000
# 74             16.203704
# 81             16.306897
# 82             16.638710
# 80             16.934483

# %%
import pandas as pd
df = pd.read_excel('dataset/SaleData.xlsx')
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
df.isnull().sum()
# Out:
# OrderDate     2
# Region        2
# Manager       2
# SalesMan      2
# Item          2
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df.dropna(inplace=True)
df.head(20)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6  2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.0      1198.0
# ...

# %%
df.groupby('SalesMan').sum()[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\4143099978.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum()[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# David      140955.0
# Diana       36100.0
# John       124016.0
# Karen       48204.0
# Luis       206373.0
# Michael     66836.0
# Shelli      33698.0
# Sigal      125037.5
# Stephen     88063.0
# Steven     199690.0

# %%
df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\2127898393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
#            Sale_amt
# SalesMan
# Shelli      33698.0
# Diana       36100.0
# Karen       48204.0
# Michael     66836.0
# Stephen     88063.0
# John       124016.0
# Sigal      125037.5
# David      140955.0
# Steven     199690.0
# Luis       206373.0
# Alexander  236703.0

# %%
df.groupby('SalesMan').sum().sort_values('Sale_amt',ascending=0)[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\3541401446.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum().sort_values('Sale_amt',ascending=0)[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# Luis       206373.0
# Steven     199690.0
# David      140955.0
# Sigal      125037.5
# John       124016.0
# Stephen     88063.0
# Michael     66836.0
# Karen       48204.0
# Diana       36100.0
# Shelli      33698.0

# %%
df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\970159690.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
#                    Sale_amt
# Manager SalesMan
# Douglas John       124016.0
#         Karen       48204.0
#         Michael     66836.0
# Hermann Luis       206373.0
#         Shelli      33698.0
#         Sigal      125037.5
# Martha  Alexander  236703.0
#         Diana       36100.0
#         Steven     199690.0
# Timothy David      140955.0
#         Stephen     88063.0

# %%
df.groupby('Manager').sum()[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\436343574.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Manager').sum()[['Sale_amt']]
#          Sale_amt
# Manager
# Douglas  239056.0
# Hermann  365108.5
# Martha   472493.0
# Timothy  229018.0

# %%
df.groupby(['SalesMan','Item']).sum()[['Units']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\3504896505.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units']]
#                         Units
# SalesMan  Item
# Alexander Cell Phone     64.0
#           Home Theater  124.0
#           Television    130.0
#           Video Games    78.0
# David     Cell Phone     27.0
#           Home Theater  126.0
#           Television     60.0
# Diana     Cell Phone     96.0
#           Home Theater   29.0
# John      Desk            2.0
#           Home Theater   87.0
#           Television     67.0
# Karen     Cell Phone     15.0
#           Home Theater   81.0
#           Video Games    74.0
# Luis      Home Theater  105.0
#           Television    126.0
#           Video Games    50.0
# ...

# %%
df.groupby(['SalesMan','Item']).sum()[['Units','Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\2129236953.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units','Sale_amt']]
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
# ...

# %%
df.groupby(['SalesMan','Item']).agg({'Units':sum,'Sale_amt':sum})
# Out:
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
#           Home Theater   81.0   40500.0
#           Video Games    74.0    4329.0
# Luis      Home Theater  105.0   52500.0
#           Television    126.0  150948.0
#           Video Games    50.0    2925.0
# Michael   Home Theater   57.0   28500.0
#           Television     32.0   38336.0
# Shelli    Desk            5.0     625.0
#           Home Theater   50.0   25000.0
# ...

# %%
df.groupby('Region').sum()[['Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\249404901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum()[['Sale_amt']]
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
 df.groupby('Item').sum()[['Units']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\2602254409.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()[['Units']]
#               Units
# Item
# Cell Phone    278.0
# Desk           10.0
# Home Theater  722.0
# Television    716.0
# Video Games   395.0

# %%
df.groupby('Item').sum()[['Units','Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\2337116634.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()[['Units','Sale_amt']]
#               Units  Sale_amt
# Item
# Cell Phone    278.0   62550.0
# Desk           10.0    1250.0
# Home Theater  722.0  361000.0
# Television    716.0  857768.0
# Video Games   395.0   23107.5

# %%
df.groupby('Item').sum().sort_values('Sale_amt')[['Units','Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\3141452899.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum().sort_values('Sale_amt')[['Units','Sale_amt']]
#               Units  Sale_amt
# Item
# Desk           10.0    1250.0
# Video Games   395.0   23107.5
# Cell Phone    278.0   62550.0
# Home Theater  722.0  361000.0
# Television    716.0  857768.0

# %%
df.groupby('Item').sum().sort_values('Sale_amt',ascending=0)[['Units','Sale_amt']]
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\90979335.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum().sort_values('Sale_amt',ascending=0)[['Units','Sale_amt']]
#               Units  Sale_amt
# Item
# Television    716.0  857768.0
# Home Theater  722.0  361000.0
# Cell Phone    278.0   62550.0
# Video Games   395.0   23107.5
# Desk           10.0    1250.0

# %%
import numpy as np
pivot=pd.pivot_table(df,index='SalesMan',aggfunc=np.mean)
pivot
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\1707906131.py:2: FutureWarning: The operation <function mean at 0x0000025C0A650D60> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pivot=pd.pivot_table(df,index='SalesMan',aggfunc=np.mean)
#                Sale_amt   Unit_price      Units
# SalesMan
# Alexander  29587.875000   529.750000  49.500000
# David      28191.000000   724.200000  42.600000
# Diana      18050.000000   362.500000  62.500000
# John       41338.666667   607.666667  52.000000
# Karen      16068.000000   261.166667  56.666667
# Luis       41274.600000   690.900000  56.200000
# Michael    33418.000000   849.000000  44.500000
# Shelli      8424.500000   185.500000  48.250000
# Sigal      41679.166667   585.500000  57.666667
# Stephen    22015.750000   512.000000  35.500000
# Steven     49922.500000  1023.500000  45.750000

# %%
import pandas as pd
from pandas import DataFrame
df = DataFrame(
               [
                ['Aryan','Singh','Full-time','administration',2,20000],
                ['Rohan','Agarwal','intern','Technical',3,50000],
                ['Riya','Shah','Full-time','administration',5,10000],
                ['Yash','Bhatia','Part-time','Technical',7,10000],
                ['Siddhant','Khanna','Full-time','Management',6,20000],
               ],columns=['First Name','Last Name','Type','Department','YoE','Salary']  
             )
df
# Out:
#   First Name Last Name       Type      Department  YoE  Salary
# 0      Aryan     Singh  Full-time  administration    2   20000
# 1      Rohan   Agarwal     intern       Technical    3   50000
# 2       Riya      Shah  Full-time  administration    5   10000
# 3       Yash    Bhatia  Part-time       Technical    7   10000
# 4   Siddhant    Khanna  Full-time      Management    6   20000

# %%
pd.pivot_table(df,index='Type')
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_1932\3965019829.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index='Type')
#                  Salary       YoE
# Type
# Full-time  16666.666667  4.333333
# Part-time  10000.000000  7.000000
# intern     50000.000000  3.000000

# %%
pd.pivot_table(df[['Salary','Type']],index='Type')
# Out:
#                  Salary
# Type
# Full-time  16666.666667
# Part-time  10000.000000
# intern     50000.000000

# %%
import pandas as pd
marks_A = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
          }
marks_A_df = pd.DataFrame(marks_A, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_B = {'Chemistry': [72,45,60,98], 
        'Physics': [78,34,72,95],  
          }
marks_B_df = pd.DataFrame(marks_B, index = ['Nandini', 'Zoya', 'Shivam', 'James'])
pd.concat([marks_A_df,marks_B_df], sort = False)
# Out:
#          Chemistry  Physics
# Subodh          67       45
# Ram             90       92
# Abdul           66       72
# John            32       40
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
pd.concat([marks_A_df,marks_B_df],sort=False)
# Out:
#          Chemistry  Physics
# Subodh          67       45
# Ram             90       92
# Abdul           66       72
# John            32       40
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
df1 = pd.DataFrame({'employee':['jyothi','sapna','raj','ramswamy'],
                   'group':['accounting','engineering','engineering','HR']})
df2 = pd.DataFrame({'employee':['jyothi','sapna','raj','ramswamy'],
                   'hier_data':[2004,2008,2012,2014]})
display(df1,df2)
# Out:
#    employee        group
# 0    jyothi   accounting
# 1     sapna  engineering
# 2       raj  engineering
# 3  ramswamy           HR
#    employee  hier_data
# 0    jyothi       2004
# 1     sapna       2008
# 2       raj       2012
# 3  ramswamy       2014

# %%
pd.concat([df1,df2],sort = False)
# Out:
#    employee        group  hier_data
# 0    jyothi   accounting        NaN
# 1     sapna  engineering        NaN
# 2       raj  engineering        NaN
# 3  ramswamy           HR        NaN
# 0    jyothi          NaN     2004.0
# 1     sapna          NaN     2008.0
# 2       raj          NaN     2012.0
# 3  ramswamy          NaN     2014.0

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#    employee        group  hier_data
# 0    jyothi   accounting       2004
# 1     sapna  engineering       2008
# 2       raj  engineering       2012
# 3  ramswamy           HR       2014

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
pd.crosstab(df['model_year'], df['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0

# %%
import numpy as np
pivot1 = pd.pivot_table(df, index = 'model_year',aggfunc=np.mean)
pivot1
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_3680\3525881494.py:2: FutureWarning: The operation <function mean at 0x000001E0DE448CC0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pivot1 = pd.pivot_table(df, index = 'model_year',aggfunc=np.mean)
#             acceleration  cylinders  displacement        mpg    origin  \
# model_year
# 70             12.948276   6.758621    281.413793  17.689655  1.310345
# 71             15.142857   5.571429    209.750000  21.250000  1.428571
# 72             15.125000   5.821429    218.375000  18.714286  1.535714
# 73             14.312500   6.375000    256.875000  17.100000  1.375000
# 74             16.203704   5.259259    171.740741  22.703704  1.666667
# 75             16.050000   5.600000    205.533333  20.266667  1.466667
# 76             15.941176   5.647059    197.794118  21.573529  1.470588
# ...

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#pandas plot
df.plot(x = 'model_year', y = 'acceleration', marker = 'o'
, kind = 'scatter');

# %%
df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_5780\2514051022.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');

# %%
df['cylinders'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x = 'weight' , y = 'mpg' , kind = 'scatter')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind = 'bar')
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_5780\4081279867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind = 'bar')
# <Axes: xlabel='cylinders'>
