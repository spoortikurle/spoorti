# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('dataset/placement.csv',)
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961240             32.225000     0.489000
# std       0.615898             19.130822     0.500129
# min       4.890000              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       9.120000            100.000000     1.000000

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(3,4))
sns.boxplot(df['cgpa'])
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(df['cgpa'])
plt.show()
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_11492\3015581030.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])

# %%
df['cgpa_zscore']=(df['cgpa'].mean())/df['cgpa'].std()

# %%
df[(df['cgpa_zscore']>3) | (df['cgpa_zscore']<-3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1    11.302588
# 1    7.46                  38.0       1    11.302588
# 2    7.54                  40.0       1    11.302588
# 3    6.42                   8.0       1    11.302588
# 4    7.23                  17.0       0    11.302588
# ..    ...                   ...     ...          ...
# 995  8.87                  44.0       1    11.302588
# 996  9.12                  65.0       1    11.302588
# 997  4.89                  34.0       0    11.302588
# 998  8.62                  46.0       1    11.302588
# 999  4.90                  10.0       1    11.302588
#
# [1000 rows x 4 columns]

# %%
plt.figure(figsize=(3,4))
sns.boxplot(df['cgpa'])
plt.show()

# %% [markdown]
# # out_iqr

# %%
plt.figure(figsize=(4,4))
sns.boxplot(df['cgpa'])
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(df['cgpa'],kde=True)
plt.show()
# Out:
# C:\Users\lab2Pc2\AppData\Local\Temp\ipykernel_11492\3075084026.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'],kde=True)

# %%
Q1=df['cgpa'].quantile(0.25)
Q3=df['cgpa'].quantile(0.75)
iqr=Q3-Q1

# %%
upper_limit=Q3+1.5*iqr
lower_limit=Q1-1.5*iqr

# %%
df[(df['cgpa']>upper_limit)  | (df['cgpa']<lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 278  5.23                  17.0       1    11.302588
# 485  4.92                  44.0       1    11.302588
# 815  5.27                  43.0       0    11.302588
# 995  8.87                  44.0       1    11.302588
# 996  9.12                  65.0       1    11.302588
# 997  4.89                  34.0       0    11.302588
# 998  8.62                  46.0       1    11.302588
# 999  4.90                  10.0       1    11.302588

# %%
df[(df['cgpa']<upper_limit)&(df['cgpa']>lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1    11.302588
# 1    7.46                  38.0       1    11.302588
# 2    7.54                  40.0       1    11.302588
# 3    6.42                   8.0       1    11.302588
# 4    7.23                  17.0       0    11.302588
# ..    ...                   ...     ...          ...
# 990  6.17                  33.0       1    11.302588
# 991  7.04                  57.0       0    11.302588
# 992  6.26                  12.0       0    11.302588
# 993  6.73                  21.0       1    11.302588
# 994  6.48                  63.0       0    11.302588
#
# [992 rows x 4 columns]

# %%
df[(df['cgpa']<upper_limit)&(df['cgpa']>lower_limit)]
plt.figure(figsize=(3,4))
sns.boxplot(df['cgpa'])
plt.show()

# %%
Q1=df['cgpa'].quantile(0.25)
Q3=df['cgpa'].quantile(0.75)
iqr=Q3-Q1

# %%
upper_limit=Q3+1.5*iqr
lower_limit=Q1-1.5*iqr

# %%
df[(df['cgpa']>upper_limit)  | (df['cgpa']<lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 278  5.23                  17.0       1    11.302588
# 485  4.92                  44.0       1    11.302588
# 815  5.27                  43.0       0    11.302588
# 995  8.87                  44.0       1    11.302588
# 996  9.12                  65.0       1    11.302588
# 997  4.89                  34.0       0    11.302588
# 998  8.62                  46.0       1    11.302588
# 999  4.90                  10.0       1    11.302588

# %%
df[(df['cgpa']<upper_limit)&(df['cgpa']>lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1    11.302588
# 1    7.46                  38.0       1    11.302588
# 2    7.54                  40.0       1    11.302588
# 3    6.42                   8.0       1    11.302588
# 4    7.23                  17.0       0    11.302588
# ..    ...                   ...     ...          ...
# 990  6.17                  33.0       1    11.302588
# 991  7.04                  57.0       0    11.302588
# 992  6.26                  12.0       0    11.302588
# 993  6.73                  21.0       1    11.302588
# 994  6.48                  63.0       0    11.302588
#
# [992 rows x 4 columns]

# %%
plt.figure(figsize=(4,4))
sns.boxplot(new_df=df['cgpa'])
plt.show()
